# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("advertising.csv")

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
X = df[["TV","Radio","Newspaper"]]
y = df[["Sales"]]
X
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2     12.0
# 3     16.5
# 4     17.9
# ..     ...
# 195    7.6
# 196   14.0
# 197   14.8
# 198   25.5
# 199   18.4
#
# [200 rows x 1 columns]

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0, test_size=60)

# %%
X_train
# Out:
#         TV  Radio  Newspaper
# 131  265.2    2.9       43.0
# 96   197.6    3.5        5.9
# 181  218.5    5.4       27.4
# 19   147.3   23.9       19.1
# 153  171.3   39.7       37.7
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [140 rows x 3 columns]

# %%
model = LinearRegression()

# %%
# supervised learning 

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_test = model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.869205273491013

# %%
# Here we are making function and using our model the one we train above 

def sales_prediction():
    # here we take budget as input from user (i.e Tv,radio,newspaper)
    tv = float(input("Enter TV ad budget: "))
    radio = float(input("Enter Radio ad budget: "))
    newspaper = float(input("Enter Newspaper ad budget: "))
    # we check min & max of our data and then i decide to write this line cuz of we enter input(budget) high model might not know about that!
    # so the model become unreliable
    if tv > 296.4 or radio > 49.6 or newspaper > 114.0:
        print("Warning: Your input is outside the training data range. Prediction might be unreliable!")

    new_data = np.array([[tv,radio,newspaper]])
    prediction = model.predict(new_data)

    print(f"The predicted sales are: ${prediction[0][0]:.2f}")

# %%
sales_prediction()
# Out:
# Enter TV ad budget:  1000000000
# Enter Radio ad budget:  2000000
# Enter Newspaper ad budget:  30
# ...
# The predicted sales are: $53871631.11
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
